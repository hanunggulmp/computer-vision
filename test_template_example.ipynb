# %% [markdown]
# # a. Import Package

# %%
import sys
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Activation
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras import callbacks
# Out:
# Using TensorFlow backend.

# %%
import torch

import torch.nn as nn
from torch.nn import init
import torchvision
from torchvision import transforms
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision.datasets as dset
from torchvision.datasets import ImageFolder

import numpy as np

# %%
imgsz = 32

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],\
std=[0.229, 0.224, 0.225])

transform_test = transforms.Compose([transforms.Resize((imgsz, imgsz)), \
                      transforms.ToTensor(), \
                        normalize])

test_raw = ImageFolder('test', transform_test)

test_loader = DataLoader(test_raw, num_workers=2,
                          shuffle=False)

# %%
print(len(train_raw))
# Out:
# 3333

# %% [markdown]
# # b. Create helper funtion

# %%
import torch.nn.functional as F  # useful stateless functions

#reshapes image data for use in a fully-connected neural network
def flatten(x):
    N = x.shape[0] # read in N, C, H, W
    return x.view(N, -1)

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return flatten(x)
    
def init_weights(m):
    # print(m)
    if type(m) == nn.Conv2d or type(m) == nn.Linear:
        random_weight(m.weight.size())
        zero_weight(m.bias.size())

# %%
def check_accuracy_module(loader, model):
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    
    with torch.no_grad():
        for x, y in loader:
            #x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            #y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 10

print('using device:', device)
# Out:
# using device: cuda

# %% [markdown]
# # c. Build model structure

# %%
channel_input = 3
channel_1 = 1024
channel_2 = 512
channel_3 = 256
num_class = 70
learning_rate = 1e-3

model = nn.Sequential(
    
    # conv1
    nn.Conv2d(channel_input, channel_1, kernel_size=5, padding=2),
    
    nn.ReLU(),
    
    # conv2
    nn.Conv2d(channel_1, channel_2, kernel_size=3, padding=2),
    
    nn.ReLU(),
    
    # conv3
    nn.Conv2d(channel_2, channel_3, kernel_size=3, padding=1),
    
    nn.ReLU(),
    
    nn.MaxPool2d(2),
    
    Flatten(),
    
    # fc
    nn.Linear(channel_3*17*17, num_class)
)

# %%
model.load_state_dict(torch.load('new_trained_model.pt'))
model.eval()
# Out:
# Sequential(
#   (0): Conv2d(3, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (1): ReLU()
#   (2): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (3): ReLU()
#   (4): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): ReLU()
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): Flatten()
#   (8): Linear(in_features=73984, out_features=70, bias=True)
# )

# %% [markdown]
# # d. Show predicted class

# %%
def show_predict_label(loader, model): 
    pred_label = []
    
    with torch.no_grad():
        for x, y in loader:
            '''x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)'''
            scores = model(x)
            _, preds = scores.max(1)
            pred_label.append(preds)
    predicted_class = np.array(pred_label)
    return predicted_class

# %%
predicted_class = show_predict_label(test_loader, model)
predicted_class_list = predicted_class.tolist()
# Out:
# tensor([38])
# tensor([15])
# tensor([36])
# tensor([4])
# tensor([14])
# tensor([41])
# tensor([9])
# tensor([41])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([37])
# tensor([1])
# tensor([0])
# tensor([21])
# tensor([18])
# tensor([15])
# tensor([2])
# tensor([1])
# tensor([15])
# tensor([68])
# tensor([15])
# tensor([15])
# tensor([60])
# tensor([15])
# tensor([4])
# tensor([40])
# tensor([16])
# tensor([32])
# tensor([66])
# tensor([15])
# tensor([68])
# tensor([17])
# tensor([16])
# tensor([14])
# tensor([4])
# tensor([27])
# tensor([28])
# tensor([18])
# tensor([23])
# tensor([40])
# tensor([54])
# tensor([8])
# tensor([64])
# tensor([14])
# tensor([67])
# tensor([15])
# tensor([59])
# tensor([15])
# tensor([15])
# tensor([2])
# tensor([0])
# tensor([17])
# tensor([37])
# tensor([49])
# tensor([15])
# tensor([18])
# tensor([2])
# tensor([15])
# tensor([23])
# tensor([60])
# tensor([41])
# tensor([0])
# tensor([41])
# tensor([30])
# tensor([37])
# tensor([24])
# tensor([18])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([42])
# tensor([2])
# tensor([37])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([25])
# tensor([58])
# tensor([66])
# tensor([6])
# tensor([4])
# tensor([0])
# tensor([1])
# tensor([41])
# tensor([16])
# tensor([15])
# tensor([42])
# tensor([39])
# tensor([6])
# tensor([41])
# tensor([13])
# tensor([67])
# tensor([67])
# tensor([52])
# tensor([64])
# tensor([37])
# tensor([58])
# tensor([15])
# tensor([32])
# tensor([39])
# tensor([15])
# tensor([16])
# tensor([8])
# tensor([16])
# tensor([15])
# tensor([42])
# tensor([65])
# tensor([0])
# tensor([1])
# tensor([15])
# tensor([41])
# tensor([41])
# tensor([15])
# tensor([12])
# tensor([20])
# tensor([15])
# tensor([60])
# tensor([18])
# tensor([18])
# tensor([15])
# tensor([15])
# tensor([9])
# tensor([15])
# tensor([18])
# tensor([15])
# tensor([68])
# tensor([10])
# tensor([58])
# tensor([32])
# tensor([15])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([11])
# tensor([15])
# tensor([15])
# tensor([16])
# tensor([8])
# tensor([31])
# tensor([9])
# tensor([37])
# tensor([22])
# tensor([42])
# tensor([15])
# tensor([18])
# tensor([15])
# tensor([17])
# tensor([17])
# tensor([37])
# tensor([15])
# tensor([58])
# tensor([13])
# tensor([42])
# tensor([23])
# tensor([15])
# tensor([65])
# tensor([5])
# tensor([43])
# tensor([16])
# tensor([12])
# tensor([39])
# tensor([15])
# tensor([58])
# tensor([63])
# tensor([64])
# tensor([15])
# tensor([16])
# tensor([15])
# tensor([24])
# tensor([15])
# tensor([24])
# tensor([41])
# tensor([15])
# tensor([4])
# tensor([38])
# tensor([37])
# tensor([0])
# tensor([17])
# tensor([2])
# tensor([4])
# tensor([37])
# tensor([38])
# tensor([39])
# tensor([41])
# tensor([20])
# tensor([3])
# tensor([32])
# tensor([15])
# tensor([3])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([59])
# tensor([18])
# tensor([58])
# tensor([58])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([18])
# tensor([16])
# tensor([43])
# tensor([58])
# tensor([18])
# tensor([17])
# tensor([22])
# tensor([4])
# tensor([13])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([2])
# tensor([23])
# tensor([37])
# tensor([26])
# tensor([15])
# tensor([11])
# tensor([23])
# tensor([4])
# tensor([18])
# tensor([41])
# tensor([9])
# tensor([15])
# tensor([56])
# tensor([16])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([54])
# tensor([58])
# tensor([0])
# tensor([69])
# tensor([15])
# tensor([15])
# tensor([56])
# tensor([69])
# tensor([15])
# tensor([15])
# tensor([19])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([16])
# tensor([0])
# tensor([4])
# tensor([15])
# tensor([12])
# tensor([15])
# tensor([37])
# tensor([2])
# tensor([2])
# tensor([15])
# tensor([17])
# tensor([2])
# tensor([16])
# tensor([37])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([22])
# tensor([15])
# tensor([57])
# tensor([25])
# tensor([22])
# tensor([58])
# tensor([68])
# tensor([58])
# tensor([4])
# tensor([4])
# tensor([29])
# tensor([15])
# tensor([15])
# tensor([40])
# tensor([52])
# tensor([37])
# tensor([14])
# tensor([45])
# tensor([37])
# tensor([25])
# tensor([58])
# tensor([15])
# tensor([16])
# tensor([58])
# tensor([41])
# tensor([15])
# tensor([37])
# tensor([41])
# tensor([16])
# tensor([15])
# tensor([9])
# tensor([15])
# tensor([2])
# tensor([9])
# tensor([60])
# tensor([68])
# tensor([16])
# tensor([15])
# tensor([19])
# tensor([15])
# tensor([2])
# tensor([2])
# tensor([19])
# tensor([32])
# tensor([45])
# tensor([15])
# tensor([15])
# tensor([37])
# tensor([13])
# tensor([25])
# tensor([37])
# tensor([41])
# tensor([9])
# tensor([9])
# tensor([3])
# tensor([9])
# tensor([15])
# tensor([2])
# tensor([22])
# tensor([60])
# tensor([15])
# tensor([60])
# tensor([1])
# tensor([2])
# tensor([17])
# tensor([23])
# tensor([15])
# tensor([69])
# tensor([58])
# tensor([23])
# tensor([37])
# tensor([18])
# tensor([39])
# tensor([58])
# tensor([15])
# tensor([15])
# tensor([19])
# tensor([20])
# tensor([41])
# tensor([39])
# tensor([58])
# tensor([41])
# tensor([23])
# tensor([49])
# tensor([15])
# tensor([58])
# tensor([39])
# tensor([15])
# tensor([25])
# tensor([69])
# tensor([2])
# tensor([15])
# tensor([11])
# tensor([39])
# tensor([68])
# tensor([26])
# tensor([39])
# tensor([40])
# tensor([16])
# tensor([2])
# tensor([15])
# tensor([16])
# tensor([64])
# tensor([4])
# tensor([68])
# tensor([2])
# tensor([18])
# tensor([4])
# tensor([23])
# tensor([5])
# tensor([50])
# tensor([15])
# tensor([16])
# tensor([60])
# tensor([11])
# tensor([15])
# tensor([15])
# tensor([11])
# tensor([15])
# tensor([37])
# tensor([15])
# tensor([3])
# tensor([15])
# tensor([45])
# tensor([18])
# tensor([14])
# tensor([15])
# tensor([2])
# tensor([18])
# tensor([15])
# tensor([68])
# tensor([16])
# tensor([18])
# tensor([22])
# tensor([3])
# tensor([43])
# tensor([58])
# tensor([2])
# tensor([26])
# tensor([18])
# tensor([15])
# tensor([17])
# tensor([42])
# tensor([28])
# tensor([2])
# tensor([58])
# tensor([16])
# tensor([52])
# tensor([19])
# tensor([2])
# tensor([64])
# tensor([58])
# tensor([65])
# tensor([2])
# tensor([40])
# tensor([15])
# tensor([8])
# tensor([52])
# tensor([19])
# tensor([45])
# tensor([49])
# tensor([15])
# tensor([3])
# tensor([66])
# tensor([22])
# tensor([44])
# tensor([40])
# tensor([15])
# tensor([15])
# tensor([41])
# tensor([45])
# tensor([16])
# tensor([58])
# tensor([22])
# tensor([18])
# tensor([48])
# tensor([15])
# tensor([63])
# tensor([69])
# tensor([31])
# tensor([15])
# tensor([2])
# tensor([52])
# tensor([64])
# tensor([41])
# tensor([2])
# tensor([69])
# tensor([58])
# tensor([4])
# tensor([67])
# tensor([15])
# tensor([2])
# tensor([6])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([69])
# tensor([0])
# tensor([15])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([9])
# tensor([9])
# tensor([11])
# tensor([11])
# tensor([32])
# tensor([30])
# tensor([15])
# tensor([4])
# tensor([16])
# tensor([4])
# tensor([21])
# tensor([4])
# tensor([2])
# tensor([43])
# tensor([15])
# tensor([21])
# tensor([2])
# tensor([2])
# tensor([17])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([34])
# tensor([4])
# tensor([17])
# tensor([15])
# tensor([56])
# tensor([44])
# tensor([8])
# tensor([7])
# tensor([9])
# tensor([30])
# tensor([15])
# tensor([15])
# tensor([16])
# tensor([16])
# tensor([32])
# tensor([22])
# tensor([15])
# tensor([19])
# tensor([2])
# tensor([56])
# tensor([63])
# tensor([2])
# tensor([19])
# tensor([47])
# tensor([8])
# tensor([18])
# tensor([23])
# tensor([16])
# tensor([52])
# tensor([27])
# tensor([63])
# tensor([14])
# tensor([4])
# tensor([15])
# tensor([11])
# tensor([15])
# tensor([49])
# tensor([67])
# tensor([51])
# tensor([52])
# tensor([17])
# tensor([67])
# tensor([61])
# tensor([15])
# tensor([16])
# tensor([6])
# tensor([40])
# tensor([4])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([34])
# tensor([17])
# tensor([54])
# tensor([68])
# tensor([67])
# tensor([68])
# tensor([67])
# tensor([4])
# tensor([38])
# tensor([6])
# tensor([25])
# tensor([41])
# tensor([15])
# tensor([20])
# tensor([22])
# tensor([67])
# tensor([54])
# tensor([68])
# tensor([68])
# tensor([18])
# tensor([2])
# tensor([38])
# tensor([6])
# tensor([54])
# tensor([67])
# tensor([18])
# tensor([46])
# tensor([39])
# tensor([30])
# tensor([15])
# tensor([46])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([21])
# tensor([15])
# tensor([47])
# tensor([45])
# tensor([38])
# tensor([32])
# tensor([15])
# tensor([31])
# tensor([66])
# tensor([15])
# tensor([15])
# tensor([45])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([2])
# tensor([42])
# tensor([29])
# tensor([2])
# tensor([20])
# tensor([2])
# tensor([4])
# tensor([53])
# tensor([47])
# tensor([44])
# tensor([16])
# tensor([15])
# tensor([29])
# tensor([23])
# tensor([49])
# tensor([15])
# tensor([15])
# tensor([29])
# tensor([47])
# tensor([4])
# tensor([47])
# tensor([66])
# tensor([31])
# tensor([12])
# tensor([66])
# tensor([15])
# tensor([15])
# tensor([18])
# tensor([15])
# tensor([29])
# tensor([9])
# tensor([29])
# tensor([16])
# tensor([31])
# tensor([15])
# tensor([57])
# tensor([3])
# tensor([46])
# tensor([41])
# tensor([19])
# tensor([58])
# tensor([15])
# tensor([1])
# tensor([1])
# tensor([58])
# tensor([15])
# tensor([2])
# tensor([25])
# tensor([37])
# tensor([49])
# tensor([30])
# tensor([54])
# tensor([60])
# tensor([9])
# tensor([8])
# tensor([15])
# tensor([32])
# tensor([9])
# tensor([8])
# tensor([11])
# tensor([24])
# tensor([18])
# tensor([16])
# tensor([21])
# tensor([51])
# tensor([20])
# tensor([9])
# tensor([46])
# tensor([16])
# tensor([2])
# tensor([21])
# tensor([69])
# tensor([20])
# tensor([29])
# tensor([7])
# tensor([46])
# tensor([38])
# tensor([21])
# tensor([5])
# tensor([15])
# tensor([16])
# tensor([19])
# tensor([2])
# tensor([15])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([8])
# tensor([35])
# tensor([15])
# tensor([2])
# tensor([30])
# tensor([18])
# tensor([9])
# tensor([15])
# tensor([18])
# tensor([4])
# tensor([45])
# tensor([16])
# tensor([2])
# tensor([17])
# tensor([15])
# tensor([46])
# tensor([15])
# tensor([21])
# tensor([15])
# tensor([31])
# tensor([10])
# tensor([7])
# tensor([15])
# tensor([32])
# tensor([22])
# tensor([41])
# tensor([18])
# tensor([56])
# tensor([45])
# tensor([53])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([60])
# tensor([15])
# tensor([0])
# tensor([65])
# tensor([46])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([37])
# tensor([2])
# tensor([7])
# tensor([48])
# tensor([16])
# tensor([11])
# tensor([12])
# tensor([66])
# tensor([7])
# tensor([31])
# tensor([15])
# tensor([15])
# tensor([54])
# tensor([17])
# tensor([15])
# tensor([15])
# tensor([18])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([21])
# tensor([15])
# tensor([2])
# tensor([2])
# tensor([41])
# tensor([41])
# tensor([15])
# tensor([42])
# tensor([2])
# tensor([16])
# tensor([40])
# tensor([0])
# tensor([2])
# tensor([15])
# tensor([23])
# tensor([15])
# tensor([4])
# tensor([27])
# tensor([4])
# tensor([59])
# tensor([58])
# tensor([58])
# tensor([4])
# tensor([58])
# tensor([42])
# tensor([17])
# tensor([17])
# tensor([41])
# tensor([4])
# tensor([4])
# tensor([24])
# tensor([2])
# tensor([15])
# tensor([55])
# tensor([61])
# tensor([32])
# tensor([2])
# tensor([16])
# tensor([56])
# tensor([62])
# tensor([15])
# tensor([42])
# tensor([33])
# tensor([4])
# tensor([4])
# tensor([56])
# tensor([2])
# tensor([16])
# tensor([12])
# tensor([44])
# tensor([30])
# tensor([30])
# tensor([69])
# tensor([16])
# tensor([16])
# tensor([30])
# tensor([4])
# tensor([15])
# tensor([44])
# tensor([29])
# tensor([60])
# tensor([30])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([4])
# tensor([15])
# tensor([37])
# tensor([62])
# tensor([20])
# tensor([8])
# tensor([54])
# tensor([44])
# tensor([8])
# tensor([19])
# tensor([67])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([32])
# tensor([45])
# tensor([46])
# tensor([58])
# tensor([55])
# tensor([15])
# tensor([49])
# tensor([33])
# tensor([2])
# tensor([15])
# tensor([43])
# tensor([15])
# tensor([40])
# tensor([66])
# tensor([66])
# tensor([15])
# tensor([4])
# tensor([22])
# tensor([10])
# tensor([15])
# tensor([8])
# tensor([45])
# tensor([54])
# tensor([15])
# tensor([18])
# tensor([15])
# tensor([30])
# tensor([26])
# tensor([47])
# tensor([15])
# tensor([7])
# tensor([15])
# tensor([16])
# tensor([52])
# tensor([29])
# tensor([58])
# tensor([18])
# tensor([8])
# tensor([29])
# tensor([11])
# tensor([31])
# tensor([4])
# tensor([66])
# tensor([20])
# tensor([29])
# tensor([27])
# tensor([55])
# tensor([46])
# tensor([9])
# tensor([42])
# tensor([15])
# tensor([20])
# tensor([9])
# tensor([12])
# tensor([18])
# tensor([15])
# tensor([2])
# tensor([69])
# tensor([50])
# tensor([30])
# tensor([23])
# tensor([15])
# tensor([27])
# tensor([15])
# tensor([40])
# tensor([15])
# tensor([15])
# tensor([38])
# tensor([37])
# tensor([9])
# tensor([58])
# tensor([15])
# tensor([20])
# tensor([15])
# tensor([4])
# tensor([21])
# tensor([4])
# tensor([56])
# tensor([2])
# tensor([15])
# tensor([38])
# tensor([68])
# tensor([59])
# tensor([19])
# tensor([43])
# tensor([26])
# tensor([4])
# tensor([16])
# tensor([16])
# tensor([37])
# tensor([16])
# tensor([16])
# tensor([12])
# tensor([18])
# tensor([36])
# tensor([12])
# tensor([28])
# tensor([8])
# tensor([58])
# tensor([3])
# tensor([59])
# tensor([31])
# tensor([6])
# tensor([47])
# tensor([65])
# tensor([48])
# tensor([16])
# tensor([15])
# tensor([0])
# tensor([67])
# tensor([38])
# tensor([0])
# tensor([14])
# tensor([15])
# tensor([4])
# tensor([56])
# tensor([40])
# tensor([18])
# tensor([2])
# tensor([18])
# tensor([41])
# tensor([18])
# tensor([44])
# tensor([39])
# tensor([20])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([18])
# tensor([15])
# tensor([4])
# tensor([25])
# tensor([15])
# tensor([5])
# tensor([7])
# tensor([40])
# tensor([2])
# tensor([2])
# tensor([4])
# tensor([56])
# tensor([37])
# tensor([43])
# tensor([22])
# tensor([57])
# tensor([2])
# tensor([54])
# tensor([15])
# tensor([18])
# tensor([16])
# tensor([37])
# tensor([29])
# tensor([17])
# tensor([15])
# tensor([58])
# tensor([15])
# tensor([15])
# tensor([44])
# tensor([56])
# tensor([15])
# tensor([58])
# tensor([22])
# tensor([66])
# tensor([2])
# tensor([33])
# tensor([8])
# tensor([23])
# tensor([25])
# tensor([29])
# tensor([29])
# tensor([4])
# tensor([35])
# tensor([22])
# tensor([51])
# tensor([32])
# tensor([16])
# tensor([15])
# tensor([17])
# tensor([15])
# tensor([2])
# tensor([65])
# tensor([65])
# tensor([20])
# tensor([15])
# tensor([8])
# tensor([18])
# tensor([2])
# tensor([33])
# tensor([45])
# tensor([61])
# tensor([39])
# tensor([40])
# tensor([15])
# tensor([45])
# tensor([52])
# tensor([40])
# tensor([15])
# tensor([19])
# tensor([15])
# tensor([15])
# tensor([1])
# tensor([67])
# tensor([9])
# tensor([42])
# tensor([28])
# tensor([46])
# tensor([9])
# tensor([18])
# tensor([2])
# tensor([6])
# tensor([15])
# tensor([15])
# tensor([18])
# tensor([16])
# tensor([2])
# tensor([2])
# tensor([16])
# tensor([43])
# tensor([9])
# tensor([22])
# tensor([50])
# tensor([32])
# tensor([40])
# tensor([2])
# tensor([57])
# tensor([31])
# tensor([41])
# tensor([2])
# tensor([49])
# tensor([13])
# tensor([18])
# tensor([20])
# tensor([53])
# tensor([16])
# tensor([14])
# tensor([15])
# tensor([19])
# tensor([15])
# tensor([41])
# tensor([37])
# tensor([58])
# tensor([15])
# tensor([2])
# tensor([23])
# tensor([68])
# tensor([48])
# tensor([15])
# tensor([14])
# tensor([23])
# tensor([38])
# tensor([15])
# tensor([56])
# tensor([38])
# tensor([15])
# tensor([43])
# tensor([39])
# tensor([24])
# tensor([15])
# tensor([10])
# tensor([33])
# tensor([54])
# tensor([23])
# tensor([17])
# tensor([55])
# tensor([22])
# tensor([26])
# tensor([52])
# tensor([13])
# tensor([8])
# tensor([63])
# tensor([14])
# tensor([9])
# tensor([44])
# tensor([58])
# tensor([60])
# tensor([16])
# tensor([38])
# tensor([22])
# tensor([47])
# tensor([69])
# tensor([49])
# tensor([15])
# tensor([69])
# tensor([50])
# tensor([57])
# tensor([9])
# tensor([18])
# tensor([19])
# tensor([67])
# tensor([2])
# tensor([15])
# tensor([41])
# tensor([2])
# tensor([17])
# tensor([15])
# tensor([22])
# tensor([27])
# tensor([23])
# tensor([0])
# tensor([7])
# tensor([15])
# tensor([41])
# tensor([16])
# tensor([9])
# tensor([4])
# tensor([19])
# tensor([63])
# tensor([68])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([63])
# tensor([2])
# tensor([18])
# tensor([15])
# tensor([15])
# tensor([59])
# tensor([10])
# tensor([4])
# tensor([30])
# tensor([21])
# tensor([59])
# tensor([69])
# tensor([15])
# tensor([15])
# tensor([17])
# tensor([47])
# tensor([57])
# tensor([15])
# tensor([46])
# tensor([15])
# tensor([16])
# tensor([18])
# tensor([15])
# tensor([44])
# tensor([15])
# tensor([38])
# tensor([17])
# tensor([54])
# tensor([2])
# tensor([54])
# tensor([15])
# tensor([60])
# tensor([16])
# tensor([15])
# tensor([60])
# tensor([17])
# tensor([24])
# tensor([15])
# tensor([65])
# tensor([15])
# tensor([9])
# tensor([58])
# tensor([18])
# tensor([15])
# tensor([68])
# tensor([24])
# tensor([2])
# tensor([17])
# tensor([2])
# tensor([52])
# tensor([67])
# tensor([41])
# tensor([23])
# tensor([9])
# tensor([57])
# tensor([2])
# tensor([16])
# tensor([44])
# tensor([62])
# tensor([3])
# tensor([15])
# tensor([19])
# tensor([16])
# tensor([26])
# tensor([15])
# tensor([9])
# tensor([63])
# tensor([4])
# tensor([6])
# tensor([15])
# tensor([4])
# tensor([16])
# tensor([18])
# tensor([38])
# tensor([50])
# tensor([69])
# tensor([15])
# tensor([15])
# tensor([16])
# tensor([46])
# tensor([40])
# tensor([15])
# tensor([40])
# tensor([37])
# tensor([22])
# tensor([56])
# tensor([15])
# tensor([4])
# tensor([39])
# tensor([6])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([59])
# tensor([15])
# tensor([48])
# tensor([18])
# tensor([9])
# tensor([15])
# tensor([41])
# tensor([18])
# tensor([48])
# tensor([16])
# tensor([34])
# tensor([18])
# tensor([58])
# tensor([58])
# tensor([62])
# tensor([60])
# tensor([17])
# tensor([15])
# tensor([47])
# tensor([2])
# tensor([15])
# tensor([40])
# tensor([8])
# tensor([27])
# tensor([45])
# tensor([2])
# tensor([16])
# tensor([19])
# tensor([4])
# tensor([9])
# tensor([68])
# tensor([11])
# tensor([15])
# tensor([69])
# tensor([6])
# tensor([2])
# tensor([15])
# tensor([6])
# tensor([61])
# tensor([30])
# tensor([40])
# tensor([45])
# tensor([58])
# tensor([15])
# tensor([9])
# tensor([68])
# tensor([43])
# tensor([28])
# tensor([29])
# tensor([31])
# tensor([4])
# tensor([50])
# tensor([15])
# tensor([17])
# tensor([68])
# tensor([15])
# tensor([64])
# tensor([4])
# tensor([15])
# tensor([11])
# tensor([15])
# tensor([61])
# tensor([15])
# tensor([4])
# tensor([58])
# tensor([38])
# tensor([19])
# tensor([15])
# tensor([18])
# tensor([15])
# tensor([68])
# tensor([15])
# tensor([2])
# tensor([38])
# tensor([49])
# tensor([15])
# tensor([2])
# tensor([47])
# tensor([58])
# tensor([44])
# tensor([69])
# tensor([42])
# tensor([29])
# tensor([15])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([21])
# tensor([21])
# tensor([42])
# tensor([2])
# tensor([49])
# tensor([14])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([37])
# tensor([37])
# tensor([37])
# tensor([15])
# tensor([28])
# tensor([26])
# tensor([23])
# tensor([10])
# tensor([52])
# tensor([48])
# tensor([4])
# tensor([37])
# tensor([69])
# tensor([38])
# tensor([57])
# tensor([57])
# tensor([35])
# tensor([42])
# tensor([2])
# tensor([23])
# tensor([58])
# tensor([18])
# tensor([34])
# tensor([2])
# tensor([5])
# tensor([15])
# tensor([51])
# tensor([64])
# tensor([22])
# tensor([66])
# tensor([58])
# tensor([41])
# tensor([33])
# tensor([22])
# tensor([46])
# tensor([52])
# tensor([61])
# tensor([15])
# tensor([26])
# tensor([15])
# tensor([60])
# tensor([30])
# tensor([52])
# tensor([15])
# tensor([15])
# tensor([52])
# tensor([19])
# tensor([51])
# tensor([67])
# tensor([41])
# tensor([43])
# tensor([52])
# tensor([19])
# tensor([15])
# tensor([9])
# tensor([27])
# tensor([52])
# tensor([15])
# tensor([0])
# tensor([15])
# tensor([23])
# tensor([18])
# tensor([28])
# tensor([44])
# tensor([61])
# tensor([46])
# tensor([60])
# tensor([17])
# tensor([31])
# tensor([46])
# tensor([13])
# tensor([50])
# tensor([64])
# tensor([2])
# tensor([2])
# tensor([24])
# tensor([68])
# tensor([2])
# tensor([26])
# tensor([46])
# tensor([18])
# tensor([58])
# tensor([15])
# tensor([23])
# tensor([15])
# tensor([21])
# tensor([4])
# tensor([9])
# tensor([39])
# tensor([50])
# tensor([24])
# tensor([37])
# tensor([26])
# tensor([2])
# tensor([19])
# tensor([18])
# tensor([19])
# tensor([41])
# tensor([2])
# tensor([50])
# tensor([15])
# tensor([23])
# tensor([31])
# tensor([35])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([16])
# tensor([68])
# tensor([59])
# tensor([6])
# tensor([2])
# tensor([24])
# tensor([21])
# tensor([15])
# tensor([49])
# tensor([42])
# tensor([15])
# tensor([15])
# tensor([69])
# tensor([24])
# tensor([20])
# tensor([4])
# tensor([8])
# tensor([15])
# tensor([4])
# tensor([15])
# tensor([28])
# tensor([2])
# tensor([8])
# tensor([41])
# tensor([63])
# tensor([4])
# tensor([16])
# tensor([56])
# tensor([4])
# tensor([26])
# tensor([52])
# tensor([8])
# tensor([62])
# tensor([33])
# tensor([47])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([52])
# tensor([11])
# tensor([66])
# tensor([58])
# tensor([15])
# tensor([65])
# tensor([3])
# tensor([2])
# tensor([37])
# tensor([64])
# tensor([3])
# tensor([41])
# tensor([16])
# tensor([2])
# tensor([18])
# tensor([21])
# tensor([52])
# tensor([15])
# tensor([2])
# tensor([9])
# tensor([15])
# tensor([20])
# tensor([8])
# tensor([58])
# tensor([54])
# tensor([3])
# tensor([19])
# tensor([18])
# tensor([58])
# tensor([19])
# tensor([58])
# tensor([24])
# tensor([49])
# tensor([13])
# tensor([2])
# tensor([3])
# tensor([16])
# tensor([15])
# tensor([24])
# tensor([15])
# tensor([2])
# tensor([52])
# tensor([37])
# tensor([17])
# tensor([40])
# tensor([38])
# tensor([32])
# tensor([15])
# tensor([17])
# tensor([60])
# tensor([41])
# tensor([51])
# tensor([25])
# tensor([9])
# tensor([8])
# tensor([6])
# tensor([47])
# tensor([26])
# tensor([18])
# tensor([16])
# tensor([2])
# tensor([15])
# tensor([58])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([47])
# tensor([27])
# tensor([0])
# tensor([37])
# tensor([65])
# tensor([3])
# tensor([51])
# tensor([3])
# tensor([2])
# tensor([16])
# tensor([40])
# tensor([22])
# tensor([39])
# tensor([2])
# tensor([41])
# tensor([38])
# tensor([52])
# tensor([15])
# tensor([69])
# tensor([34])
# tensor([48])
# tensor([2])
# tensor([15])
# tensor([65])
# tensor([22])
# tensor([2])
# tensor([35])
# tensor([63])
# tensor([15])
# tensor([61])
# tensor([50])
# tensor([5])
# tensor([15])
# tensor([63])
# tensor([15])
# tensor([34])
# tensor([3])
# tensor([18])
# tensor([15])
# tensor([14])
# tensor([26])
# tensor([41])
# tensor([24])
# tensor([4])
# tensor([58])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([58])
# tensor([59])
# tensor([15])
# tensor([17])
# tensor([52])
# tensor([4])
# tensor([46])
# tensor([15])
# tensor([15])
# tensor([38])
# tensor([30])
# tensor([53])
# tensor([68])
# tensor([2])
# tensor([4])
# tensor([4])
# tensor([49])
# tensor([27])
# tensor([42])
# tensor([23])
# tensor([17])
# tensor([48])
# tensor([51])
# tensor([15])
# tensor([15])
# tensor([12])
# tensor([37])
# tensor([61])
# tensor([65])
# tensor([24])
# tensor([9])
# tensor([18])
# tensor([58])
# tensor([51])
# tensor([39])
# tensor([8])
# tensor([23])
# tensor([58])
# tensor([2])
# tensor([7])
# tensor([37])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([1])
# tensor([27])
# tensor([46])
# tensor([15])
# tensor([58])
# tensor([52])
# tensor([15])
# tensor([17])
# tensor([17])
# tensor([39])
# tensor([52])
# tensor([18])
# tensor([19])
# tensor([15])
# tensor([19])
# tensor([61])
# tensor([9])
# tensor([15])
# tensor([18])
# tensor([2])
# tensor([41])
# tensor([58])
# tensor([46])
# tensor([46])
# tensor([65])
# tensor([15])
# tensor([55])
# tensor([15])
# tensor([16])
# tensor([40])
# tensor([34])
# tensor([6])
# tensor([16])
# tensor([18])
# tensor([66])
# tensor([20])
# tensor([43])
# tensor([43])
# tensor([4])
# tensor([23])
# tensor([16])
# tensor([69])
# tensor([4])
# tensor([19])
# tensor([43])
# tensor([22])
# tensor([15])
# tensor([20])
# tensor([2])
# tensor([52])
# tensor([53])
# tensor([45])
# tensor([53])
# tensor([58])
# tensor([23])
# tensor([8])
# tensor([4])
# tensor([4])
# tensor([2])
# tensor([58])
# tensor([15])
# tensor([15])
# tensor([6])
# tensor([2])
# tensor([25])
# tensor([6])
# tensor([2])
# tensor([18])
# tensor([44])
# tensor([55])
# tensor([44])
# tensor([39])
# tensor([23])
# tensor([58])
# tensor([8])
# tensor([19])
# tensor([2])
# tensor([20])
# tensor([53])
# tensor([23])
# tensor([44])
# tensor([53])
# tensor([47])
# tensor([68])
# tensor([15])
# tensor([45])
# tensor([38])
# tensor([4])
# tensor([55])
# tensor([46])
# tensor([20])
# tensor([15])
# tensor([58])
# tensor([43])
# tensor([55])
# tensor([69])
# tensor([43])
# tensor([2])
# tensor([63])
# tensor([15])
# tensor([38])
# tensor([38])
# tensor([18])
# tensor([63])
# tensor([10])
# tensor([52])
# tensor([68])
# tensor([8])
# tensor([27])
# tensor([27])
# tensor([36])
# tensor([41])
# tensor([9])
# tensor([16])
# tensor([4])
# tensor([47])
# tensor([66])
# tensor([20])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([34])
# tensor([58])
# tensor([58])
# tensor([46])
# tensor([23])
# tensor([18])
# tensor([54])
# tensor([41])
# tensor([2])
# tensor([14])
# tensor([69])
# tensor([12])
# tensor([16])
# tensor([2])
# tensor([9])
# tensor([44])
# tensor([14])
# tensor([37])
# tensor([18])
# tensor([19])
# tensor([61])
# tensor([58])
# tensor([16])
# tensor([23])
# tensor([30])
# tensor([16])
# tensor([48])
# tensor([38])
# tensor([58])
# tensor([40])
# tensor([15])
# tensor([13])
# tensor([58])
# tensor([23])
# tensor([15])
# tensor([46])
# tensor([18])
# tensor([69])
# tensor([2])
# tensor([68])
# tensor([15])
# tensor([44])
# tensor([22])
# tensor([52])
# tensor([6])
# tensor([23])
# tensor([33])
# tensor([44])
# tensor([66])
# tensor([26])
# tensor([16])
# tensor([26])
# tensor([67])
# tensor([58])
# tensor([17])
# tensor([4])
# tensor([16])
# tensor([58])
# tensor([26])
# tensor([22])
# tensor([60])
# tensor([19])
# tensor([33])
# tensor([9])
# tensor([18])
# tensor([50])
# tensor([16])
# tensor([9])
# tensor([28])
# tensor([68])
# tensor([23])
# tensor([30])
# tensor([65])
# tensor([30])
# tensor([68])
# tensor([12])
# tensor([2])
# tensor([15])
# tensor([63])
# tensor([12])
# tensor([2])
# tensor([42])
# tensor([58])
# tensor([40])
# tensor([46])
# tensor([26])
# tensor([15])
# tensor([61])
# tensor([7])
# tensor([35])
# tensor([4])
# tensor([19])
# tensor([49])
# tensor([4])
# tensor([41])
# tensor([15])
# tensor([62])
# tensor([2])
# tensor([15])
# tensor([17])
# tensor([3])
# tensor([45])
# tensor([8])
# tensor([19])
# tensor([43])
# tensor([25])
# tensor([15])
# tensor([27])
# tensor([15])
# tensor([16])
# tensor([15])
# tensor([26])
# tensor([25])
# tensor([14])
# tensor([39])
# tensor([45])
# tensor([29])
# tensor([17])
# tensor([15])
# tensor([23])
# tensor([2])
# tensor([29])
# tensor([4])
# tensor([63])
# tensor([15])
# tensor([45])
# tensor([62])
# tensor([16])
# tensor([15])
# tensor([10])
# tensor([25])
# tensor([58])
# tensor([11])
# tensor([41])
# tensor([39])
# tensor([4])
# tensor([47])
# tensor([21])
# tensor([17])
# tensor([56])
# tensor([29])
# tensor([38])
# tensor([57])
# tensor([15])
# tensor([36])
# tensor([14])
# tensor([66])
# tensor([4])
# tensor([15])
# tensor([40])
# tensor([46])
# tensor([4])
# tensor([15])
# tensor([17])
# tensor([15])
# tensor([15])
# tensor([33])
# tensor([16])
# tensor([11])
# tensor([18])
# tensor([23])
# tensor([19])
# tensor([15])
# tensor([15])
# tensor([48])
# tensor([15])
# tensor([15])
# tensor([21])
# tensor([43])
# tensor([8])
# tensor([62])
# tensor([22])
# tensor([15])
# tensor([4])
# tensor([23])
# tensor([10])
# tensor([2])
# tensor([7])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([27])
# tensor([52])
# tensor([15])
# tensor([26])
# tensor([15])
# tensor([17])
# tensor([15])
# tensor([66])
# tensor([46])
# tensor([23])
# tensor([40])
# tensor([17])
# tensor([61])
# tensor([2])
# tensor([21])
# tensor([3])
# tensor([17])
# tensor([2])
# tensor([44])
# tensor([34])
# tensor([34])
# tensor([20])
# tensor([44])
# tensor([45])
# tensor([44])
# tensor([15])
# tensor([44])
# tensor([31])
# tensor([4])
# tensor([16])
# tensor([61])
# tensor([66])
# tensor([2])
# tensor([51])
# tensor([15])
# tensor([37])
# tensor([44])
# tensor([17])
# tensor([45])
# tensor([66])
# tensor([53])
# tensor([42])
# tensor([24])
# tensor([22])
# tensor([15])
# tensor([19])
# tensor([58])
# tensor([15])
# tensor([6])
# tensor([68])
# tensor([36])
# tensor([46])
# tensor([49])
# tensor([10])
# tensor([58])
# tensor([19])
# tensor([49])
# tensor([2])
# tensor([7])
# tensor([18])
# tensor([52])
# tensor([37])
# tensor([46])
# tensor([44])
# tensor([15])
# tensor([4])
# tensor([63])
# tensor([65])
# tensor([33])
# tensor([52])
# tensor([50])
# tensor([41])
# tensor([26])
# tensor([47])
# tensor([41])
# tensor([58])
# tensor([22])
# tensor([36])
# tensor([26])
# tensor([14])
# tensor([43])
# tensor([47])
# tensor([23])
# tensor([2])
# tensor([15])
# tensor([27])
# tensor([15])
# tensor([25])
# tensor([24])
# tensor([19])
# tensor([2])
# tensor([61])
# tensor([61])
# tensor([15])
# tensor([2])
# tensor([54])
# tensor([19])
# tensor([18])
# tensor([15])
# tensor([27])
# tensor([23])
# tensor([16])
# tensor([15])
# tensor([65])
# tensor([38])
# tensor([38])
# tensor([49])
# tensor([6])
# tensor([63])
# tensor([62])
# tensor([36])
# tensor([2])
# tensor([15])
# tensor([52])
# tensor([52])
# tensor([2])
# tensor([4])
# tensor([9])
# tensor([27])
# tensor([29])
# tensor([29])
# tensor([9])
# tensor([68])
# tensor([17])
# tensor([9])
# tensor([18])
# tensor([15])
# tensor([58])
# tensor([46])
# tensor([15])
# tensor([10])
# tensor([17])
# tensor([55])
# tensor([15])
# tensor([5])
# tensor([33])
# tensor([15])
# tensor([23])
# tensor([36])
# tensor([45])
# tensor([52])
# tensor([38])
# tensor([46])
# tensor([52])
# tensor([55])
# tensor([38])
# tensor([22])
# tensor([50])
# tensor([58])
# tensor([4])
# tensor([16])
# tensor([15])
# tensor([36])
# tensor([26])
# tensor([58])
# tensor([18])
# tensor([6])
# tensor([15])
# tensor([47])
# tensor([69])
# tensor([27])
# tensor([40])
# tensor([41])
# tensor([4])
# tensor([15])
# tensor([54])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([8])
# tensor([15])
# tensor([19])
# tensor([56])
# tensor([16])
# tensor([36])
# tensor([15])
# tensor([43])
# tensor([15])
# tensor([42])
# tensor([52])
# tensor([50])
# tensor([15])
# tensor([15])
# tensor([30])
# tensor([37])
# tensor([48])
# tensor([23])
# tensor([2])
# tensor([2])
# tensor([19])
# tensor([54])
# tensor([6])
# tensor([15])
# tensor([16])
# tensor([40])
# tensor([19])
# tensor([15])
# tensor([15])
# tensor([61])
# tensor([25])
# tensor([22])
# tensor([58])
# tensor([4])
# tensor([26])
# tensor([15])
# tensor([62])
# tensor([18])
# tensor([4])
# tensor([2])
# tensor([30])
# tensor([4])
# tensor([23])
# tensor([16])
# tensor([43])
# tensor([6])
# tensor([2])
# tensor([51])
# tensor([17])
# tensor([15])
# tensor([55])
# tensor([11])
# tensor([34])
# tensor([22])
# tensor([13])
# tensor([18])
# tensor([41])
# tensor([16])
# tensor([15])
# tensor([19])
# tensor([63])
# tensor([2])
# tensor([62])
# tensor([37])
# tensor([68])
# tensor([52])
# tensor([41])
# tensor([23])
# tensor([15])
# tensor([65])
# tensor([13])
# tensor([9])
# tensor([45])
# tensor([9])
# tensor([47])
# tensor([24])
# tensor([4])
# tensor([41])
# tensor([65])
# tensor([43])
# tensor([44])
# tensor([44])
# tensor([52])
# tensor([19])
# tensor([55])
# tensor([16])
# tensor([16])
# tensor([25])
# tensor([18])
# tensor([52])
# tensor([4])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([30])
# tensor([16])
# tensor([34])
# tensor([4])
# tensor([12])
# tensor([30])
# tensor([12])
# tensor([16])
# tensor([18])
# tensor([28])
# tensor([23])
# tensor([3])
# tensor([18])
# tensor([42])
# tensor([62])
# tensor([27])
# tensor([34])
# tensor([51])
# tensor([8])
# tensor([65])
# tensor([2])
# tensor([24])
# tensor([26])
# tensor([16])
# tensor([40])
# tensor([25])
# tensor([23])
# tensor([2])
# tensor([15])
# tensor([21])
# tensor([41])
# tensor([9])
# tensor([22])
# tensor([46])
# tensor([0])
# tensor([47])
# tensor([15])
# tensor([61])
# tensor([15])
# tensor([15])
# tensor([17])
# tensor([15])
# tensor([37])
# tensor([15])
# tensor([69])
# tensor([56])
# tensor([41])
# tensor([26])
# tensor([9])
# tensor([2])
# tensor([68])
# tensor([62])
# tensor([47])
# tensor([1])
# tensor([49])
# tensor([16])
# tensor([15])
# tensor([23])
# tensor([58])
# tensor([59])
# tensor([5])
# tensor([15])
# tensor([19])
# tensor([18])
# tensor([10])
# tensor([26])
# tensor([17])
# tensor([15])
# tensor([22])
# tensor([3])
# tensor([15])
# tensor([15])
# tensor([6])
# tensor([2])
# tensor([38])
# tensor([4])
# tensor([17])
# tensor([15])
# tensor([15])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([41])
# tensor([39])
# tensor([15])
# tensor([15])
# tensor([4])
# tensor([48])
# tensor([53])
# tensor([62])
# tensor([31])
# tensor([24])
# tensor([30])
# tensor([15])
# tensor([15])
# tensor([20])
# tensor([0])
# tensor([45])
# tensor([66])
# tensor([66])
# tensor([58])
# tensor([15])
# tensor([4])
# tensor([15])
# tensor([64])
# tensor([2])
# tensor([15])
# tensor([17])
# tensor([30])
# tensor([6])
# tensor([2])
# tensor([34])
# tensor([16])
# tensor([53])
# tensor([55])
# tensor([61])
# tensor([15])
# tensor([18])
# tensor([17])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([43])
# tensor([65])
# tensor([15])
# tensor([61])
# tensor([20])
# tensor([8])
# tensor([10])
# tensor([15])
# tensor([68])
# tensor([25])
# tensor([16])
# tensor([4])
# tensor([27])
# tensor([15])
# tensor([16])
# tensor([68])
# tensor([65])
# tensor([65])
# tensor([19])
# tensor([2])
# tensor([11])
# tensor([61])
# tensor([45])
# tensor([24])
# tensor([62])
# tensor([67])
# tensor([5])
# tensor([2])
# tensor([15])
# tensor([45])
# tensor([44])
# tensor([30])
# tensor([63])
# tensor([62])
# tensor([17])
# tensor([40])
# tensor([17])
# tensor([9])
# tensor([41])
# tensor([2])
# tensor([22])
# tensor([44])
# tensor([58])
# tensor([4])
# tensor([32])
# tensor([40])
# tensor([17])
# tensor([5])
# tensor([62])
# tensor([24])
# tensor([24])
# tensor([15])
# tensor([9])
# tensor([26])
# tensor([15])
# tensor([8])
# tensor([29])
# tensor([66])
# tensor([18])
# tensor([16])
# tensor([52])
# tensor([44])
# tensor([66])
# tensor([4])
# tensor([19])
# tensor([16])
# tensor([16])
# tensor([46])
# tensor([19])
# tensor([37])
# tensor([3])
# tensor([52])
# tensor([52])
# tensor([52])
# tensor([16])
# tensor([59])
# tensor([55])
# tensor([20])
# tensor([34])
# tensor([52])
# tensor([54])
# tensor([16])
# tensor([24])
# tensor([3])
# tensor([16])
# tensor([51])
# tensor([15])
# tensor([62])
# tensor([36])
# tensor([16])
# tensor([47])
# tensor([10])
# tensor([55])
# tensor([9])
# tensor([19])
# tensor([17])
# tensor([9])
# tensor([9])
# tensor([68])
# tensor([19])
# tensor([4])
# tensor([0])
# tensor([15])
# tensor([53])
# tensor([2])
# tensor([22])
# tensor([52])
# tensor([15])
# tensor([61])
# tensor([26])
# tensor([61])
# tensor([52])
# tensor([51])
# tensor([15])
# tensor([47])
# tensor([40])
# tensor([13])
# tensor([16])
# tensor([61])
# tensor([61])
# tensor([16])
# tensor([5])
# tensor([40])
# tensor([15])
# tensor([17])
# tensor([16])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([60])
# tensor([22])
# tensor([61])
# tensor([41])
# tensor([41])
# tensor([62])
# tensor([24])
# tensor([15])
# tensor([15])
# tensor([9])
# tensor([18])
# tensor([2])
# tensor([18])
# tensor([15])
# tensor([15])
# tensor([52])
# tensor([40])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([2])
# tensor([4])
# tensor([10])
# tensor([42])
# tensor([20])
# tensor([24])
# tensor([62])
# tensor([61])
# tensor([34])
# tensor([40])
# tensor([41])
# tensor([40])
# tensor([15])
# tensor([2])
# tensor([52])
# tensor([5])
# tensor([2])
# tensor([10])
# tensor([13])
# tensor([1])
# tensor([29])
# tensor([4])
# tensor([15])
# tensor([45])
# tensor([15])
# tensor([23])
# tensor([19])
# tensor([45])
# tensor([15])
# tensor([13])
# tensor([2])
# tensor([53])
# tensor([43])
# tensor([3])
# tensor([23])
# tensor([52])
# tensor([4])
# tensor([19])
# tensor([19])
# tensor([61])
# tensor([19])
# tensor([19])
# tensor([24])
# tensor([2])
# tensor([16])
# tensor([16])
# tensor([16])
# tensor([15])
# tensor([15])
# tensor([43])
# tensor([53])
# tensor([58])
# tensor([15])
# tensor([58])
# tensor([62])
# tensor([15])
# tensor([3])
# tensor([15])
# tensor([46])
# tensor([15])
# tensor([43])
# tensor([23])
# tensor([56])
# tensor([18])
# tensor([17])
# tensor([59])
# tensor([43])
# tensor([2])
# tensor([15])
# tensor([2])
# tensor([44])
# tensor([47])
# tensor([41])
# tensor([54])
# tensor([6])
# tensor([23])
# tensor([3])
# tensor([8])
# tensor([24])
# tensor([4])
# tensor([66])
# tensor([15])
# tensor([41])
# tensor([0])
# tensor([15])
# tensor([2])
# tensor([15])
# tensor([34])
# tensor([41])
# tensor([39])
# tensor([41])
# tensor([43])
# tensor([5])
# tensor([2])
# tensor([61])
# tensor([9])
# tensor([22])
# tensor([65])
# tensor([46])
# tensor([39])
# tensor([68])
# tensor([11])
# tensor([32])
# tensor([29])
# tensor([53])
# tensor([15])
# tensor([9])
# tensor([63])
# tensor([66])
# tensor([19])
# tensor([21])
# tensor([15])
# tensor([53])
# tensor([15])
# tensor([44])
# tensor([45])
# tensor([41])
# tensor([15])
# tensor([40])
# tensor([4])
# tensor([53])
# tensor([15])
# tensor([15])
# tensor([42])
# tensor([29])
# tensor([26])
# tensor([38])
# tensor([42])
# tensor([4])
# tensor([2])
# tensor([44])
# tensor([44])
# tensor([9])
# tensor([11])
# tensor([36])
# tensor([25])
# tensor([26])
# tensor([4])
# tensor([15])
# tensor([26])
# tensor([15])
# tensor([26])
# tensor([60])
# tensor([34])
# tensor([62])
# tensor([15])
# tensor([52])
# tensor([38])
# tensor([33])
# tensor([61])
# tensor([18])
# tensor([19])
# tensor([30])
# tensor([40])
# tensor([35])
# tensor([32])
# tensor([53])
# tensor([23])
# tensor([31])
# tensor([9])
# tensor([16])
# tensor([46])
# tensor([15])
# tensor([37])
# tensor([10])
# tensor([9])
# tensor([29])
# tensor([2])
# tensor([44])
# tensor([42])
# tensor([60])
# tensor([44])
# tensor([15])
# tensor([58])
# tensor([15])
# tensor([2])
# tensor([2])
# tensor([6])
# tensor([19])
# tensor([55])
# tensor([3])
# tensor([43])
# tensor([23])
# tensor([40])
# tensor([10])
# tensor([15])
# tensor([31])
# tensor([2])
# tensor([52])
# tensor([15])
# tensor([26])
# tensor([58])
# tensor([46])
# tensor([64])
# tensor([2])
# tensor([1])
# tensor([45])
# tensor([15])
# tensor([23])
# tensor([2])
# tensor([4])
# tensor([50])
# tensor([51])
# tensor([2])
# tensor([17])
# tensor([15])
# tensor([5])
# tensor([45])
# tensor([19])
# tensor([15])
# tensor([63])
# tensor([63])
# tensor([4])
# tensor([16])
# tensor([25])
# tensor([65])
# tensor([15])
# tensor([19])
# tensor([3])
# tensor([16])
# tensor([2])
# tensor([36])
# tensor([15])
# tensor([35])
# tensor([36])
# tensor([24])
# tensor([56])
# tensor([15])
# tensor([15])
# tensor([23])
# tensor([2])
# tensor([5])
# tensor([37])
# tensor([52])
# tensor([13])
# tensor([2])
# tensor([17])
# tensor([15])
# tensor([15])
# tensor([7])
# tensor([13])
# tensor([4])
# tensor([41])
# tensor([19])
# tensor([62])
# tensor([41])
# tensor([15])
# tensor([62])
# tensor([15])
# tensor([19])
# tensor([2])
# tensor([18])
# tensor([0])
# tensor([15])
# tensor([65])
# tensor([44])
# tensor([65])
# tensor([15])
# tensor([16])
# tensor([15])
# tensor([40])
# tensor([18])
# tensor([26])
# tensor([58])
# tensor([16])
# tensor([29])
# tensor([17])
# tensor([15])
# tensor([54])
# tensor([6])
# tensor([19])
# tensor([47])
# tensor([18])
# tensor([15])
# tensor([15])
# tensor([19])
# tensor([15])
# tensor([3])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([32])
# tensor([0])
# tensor([15])
# tensor([33])
# tensor([15])
# tensor([2])
# tensor([13])
# tensor([15])
# tensor([0])
# tensor([3])
# tensor([15])
# tensor([22])
# tensor([41])
# tensor([30])
# tensor([16])
# tensor([65])
# tensor([26])
# tensor([46])
# tensor([4])
# tensor([9])
# tensor([15])
# tensor([24])
# tensor([5])
# tensor([17])
# tensor([64])
# tensor([41])
# tensor([16])
# tensor([41])
# tensor([62])
# tensor([15])
# tensor([19])
# tensor([4])
# tensor([15])
# tensor([42])
# tensor([15])
# tensor([40])
# tensor([19])
# tensor([66])
# tensor([10])
# tensor([49])
# tensor([21])
# tensor([18])
# tensor([3])
# tensor([15])
# tensor([44])
# tensor([53])
# tensor([15])
# tensor([63])
# tensor([7])
# tensor([9])
# tensor([18])
# tensor([48])
# tensor([15])
# tensor([40])
# tensor([59])
# tensor([47])
# tensor([15])
# tensor([59])
# tensor([0])
# tensor([52])
# tensor([22])
# tensor([15])
# tensor([15])
# tensor([16])
# tensor([51])
# tensor([9])
# tensor([4])
# tensor([2])
# tensor([15])
# tensor([1])
# tensor([15])
# tensor([23])
# tensor([30])
# tensor([66])
# tensor([15])
# tensor([26])
# tensor([15])
# tensor([18])
# tensor([61])
# tensor([33])
# tensor([21])
# tensor([18])
# tensor([27])
# tensor([47])
# tensor([2])
# tensor([44])
# tensor([15])
# tensor([33])
# tensor([2])
# tensor([47])
# tensor([19])
# tensor([19])
# tensor([15])
# tensor([30])
# tensor([18])
# tensor([15])
# tensor([5])
# tensor([43])
# tensor([58])
# tensor([15])
# tensor([15])
# tensor([21])
# tensor([41])
# tensor([46])
# tensor([40])
# tensor([17])
# tensor([1])
# tensor([44])
# tensor([15])
# tensor([44])
# tensor([9])
# tensor([15])
# tensor([7])
# tensor([68])
# tensor([17])
# tensor([15])
# tensor([5])
# tensor([15])
# tensor([19])
# tensor([16])
# tensor([15])
# tensor([18])
# tensor([16])
# tensor([9])
# tensor([23])
# tensor([15])
# tensor([66])
# tensor([18])
# tensor([2])
# tensor([9])
# tensor([4])
# tensor([39])
# tensor([9])
# tensor([66])
# tensor([26])
# tensor([65])
# tensor([39])
# tensor([53])
# tensor([2])
# tensor([46])
# tensor([51])
# tensor([23])
# tensor([33])
# tensor([5])
# tensor([15])
# tensor([33])
# tensor([20])
# tensor([10])
# tensor([33])
# tensor([15])
# tensor([23])
# tensor([8])
# tensor([39])
# tensor([66])
# tensor([4])
# tensor([52])
# tensor([14])
# tensor([23])
# tensor([4])
# tensor([35])
# tensor([35])
# tensor([18])
# tensor([35])
# tensor([42])
# tensor([48])
# tensor([19])
# tensor([35])
# tensor([50])
# tensor([43])
# tensor([31])
# tensor([35])
# tensor([15])
# tensor([19])
# tensor([35])
# tensor([51])
# tensor([40])
# tensor([36])
# tensor([9])
# tensor([35])
# tensor([43])
# tensor([35])
# tensor([35])
# tensor([18])
# tensor([35])
# tensor([2])
# tensor([52])
# tensor([9])
# tensor([9])
# tensor([48])
# tensor([15])
# tensor([35])
# tensor([57])
# tensor([41])
# tensor([36])
# tensor([15])
# tensor([58])
# tensor([62])
# tensor([41])
# tensor([41])
# tensor([14])
# tensor([18])
# tensor([58])
# tensor([10])
# tensor([43])
# tensor([18])
# tensor([15])
# tensor([15])
# tensor([18])
# tensor([18])
# tensor([4])
# tensor([46])
# tensor([6])
# tensor([32])
# tensor([15])
# tensor([30])
# tensor([9])
# tensor([4])
# tensor([15])
# tensor([40])
# tensor([15])
# tensor([37])
# tensor([15])
# tensor([2])
# tensor([27])
# tensor([19])
# tensor([15])
# tensor([19])
# tensor([45])
# tensor([58])
# tensor([3])
# tensor([65])
# tensor([24])
# tensor([2])
# tensor([27])
# tensor([33])
# tensor([5])
# tensor([4])
# tensor([9])
# tensor([5])
# tensor([4])
# tensor([15])
# tensor([15])
# tensor([19])
# tensor([52])
# tensor([15])
# tensor([63])
# tensor([2])
# tensor([13])
# tensor([2])
# tensor([52])
# tensor([40])
# tensor([1])
# tensor([40])
# tensor([62])
# tensor([53])
# tensor([7])
# tensor([18])
# tensor([43])
# tensor([15])
# tensor([15])
# tensor([2])
# tensor([5])
# tensor([27])
# tensor([7])
# tensor([39])
# tensor([7])
# tensor([18])
# tensor([62])
# tensor([29])
# tensor([6])
# tensor([40])
# tensor([41])
# tensor([2])
# tensor([19])
# tensor([26])
# tensor([15])
# tensor([48])
# tensor([4])
# tensor([18])
# tensor([19])
# tensor([36])
# tensor([3])
# tensor([4])
# tensor([5])
# tensor([17])
# tensor([2])
# tensor([51])
# tensor([26])
# tensor([15])
# tensor([15])
# tensor([4])
# tensor([19])
# tensor([6])
# tensor([15])
# tensor([49])
# tensor([6])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([5])
# tensor([19])
# tensor([47])
# tensor([43])
# tensor([15])
# tensor([52])
# tensor([33])
# tensor([65])
# tensor([16])
# tensor([15])
# tensor([9])
# tensor([33])
# tensor([49])
# tensor([24])
# tensor([36])
# tensor([40])
# tensor([45])
# tensor([40])
# tensor([58])
# tensor([5])
# tensor([45])
# tensor([26])
# tensor([57])
# tensor([15])
# tensor([15])
# tensor([49])
# tensor([66])
# tensor([66])
# tensor([15])
# tensor([45])
# tensor([45])
# tensor([44])
# tensor([44])
# tensor([9])
# tensor([15])
# tensor([30])
# tensor([12])
# tensor([3])
# tensor([0])
# tensor([5])
# tensor([23])
# tensor([62])
# tensor([42])
# tensor([23])
# tensor([7])
# tensor([46])
# tensor([63])
# tensor([51])
# tensor([58])
# tensor([17])
# tensor([15])
# tensor([29])
# tensor([18])
# tensor([20])
# tensor([46])
# tensor([15])
# tensor([15])
# tensor([38])
# tensor([15])
# tensor([26])
# tensor([63])
# tensor([46])
# tensor([4])
# tensor([15])
# tensor([26])
# tensor([43])
# tensor([15])
# tensor([25])
# tensor([52])
# tensor([18])
# tensor([19])
# tensor([10])
# tensor([52])
# tensor([62])
# tensor([3])
# tensor([15])
# tensor([37])
# tensor([2])
# tensor([9])
# tensor([62])
# tensor([15])
# tensor([64])
# tensor([24])
# tensor([2])
# tensor([36])
# tensor([62])
# tensor([4])
# tensor([65])
# tensor([15])
# tensor([34])
# tensor([43])
# tensor([15])
# tensor([69])
# tensor([41])
# tensor([52])
# tensor([34])
# tensor([27])
# tensor([36])
# tensor([45])
# tensor([15])
# tensor([53])
# tensor([37])
# tensor([2])
# tensor([34])
# tensor([41])
# tensor([38])
# tensor([36])
# tensor([15])
# tensor([23])
# tensor([13])
# tensor([2])
# tensor([40])
# tensor([46])
# tensor([60])
# tensor([30])
# tensor([53])
# tensor([2])
# tensor([4])
# tensor([10])
# tensor([18])
# tensor([2])
# tensor([15])
# tensor([24])
# tensor([42])
# tensor([15])
# tensor([15])
# tensor([26])
# tensor([19])
# tensor([18])
# tensor([49])
# tensor([49])
# tensor([58])
# tensor([6])
# tensor([23])
# tensor([62])
# tensor([18])
# tensor([34])
# tensor([46])
# tensor([52])
# tensor([34])
# tensor([15])
# tensor([22])
# tensor([2])
# tensor([7])
# tensor([27])
# tensor([36])
# tensor([10])
# tensor([43])
# tensor([15])
# tensor([22])
# tensor([15])
# tensor([60])
# tensor([5])
# tensor([26])
# tensor([45])
# tensor([26])
# tensor([62])
# tensor([40])
# tensor([19])
# tensor([18])
# tensor([7])
# tensor([2])
# tensor([4])
# tensor([59])
# tensor([48])
# tensor([40])
# tensor([41])
# tensor([19])
# tensor([33])
# tensor([2])
# tensor([7])
# tensor([13])
# tensor([18])
# tensor([4])
# tensor([29])
# tensor([18])
# tensor([48])
# tensor([15])
# tensor([25])
# tensor([26])
# tensor([15])
# tensor([15])
# tensor([15])
# tensor([33])
# tensor([2])
# tensor([40])
# tensor([5])
# tensor([43])
# tensor([58])
# tensor([36])
# tensor([2])
# tensor([17])
# tensor([21])
# tensor([4])
# tensor([37])
# tensor([62])
# tensor([36])
# tensor([18])
# tensor([19])
# tensor([0])
# tensor([2])
# tensor([15])
# tensor([7])
# tensor([48])
# tensor([37])
# tensor([2])
# tensor([15])
# tensor([15])
# tensor([24])
# tensor([18])
# tensor([29])
# tensor([15])
# tensor([7])
# tensor([52])
# tensor([46])
# tensor([15])
# tensor([19])
# tensor([3])
# tensor([19])
# tensor([4])
# tensor([47])
# tensor([15])
# tensor([15])
# tensor([53])
# tensor([15])
# tensor([15])
# tensor([46])
# tensor([61])
# tensor([16])
# tensor([15])
# tensor([23])
# tensor([34])
# tensor([4])
# tensor([62])
# tensor([26])
# tensor([15])
# tensor([19])
# tensor([19])
# tensor([4])
# tensor([15])
# tensor([36])
# tensor([6])
# tensor([15])
# tensor([59])
# tensor([15])
# tensor([15])
# tensor([8])
# tensor([15])
# tensor([58])
# tensor([62])
# tensor([0])
# tensor([15])
# tensor([50])
# tensor([17])
# tensor([4])
# tensor([32])
# tensor([15])
# tensor([2])
# tensor([45])
# tensor([2])
# tensor([58])
# tensor([15])
# tensor([3])
# tensor([5])
# tensor([19])
# tensor([41])
# tensor([2])
# tensor([58])
# tensor([26])
# tensor([37])
# tensor([16])
# tensor([18])
# tensor([15])
# tensor([62])
# tensor([18])
# tensor([15])
# tensor([46])
# tensor([61])
# tensor([15])
# tensor([17])
# tensor([2])
# tensor([19])
# tensor([36])
# tensor([4])
# tensor([26])

# %%
print(predicted_class_list[:10])
# Out:
# [38, 15, 36, 4, 14, 41, 9, 41, 4, 4]

# %%
from sklearn.metrics import classification_report, accuracy_score, f1_score

# class target for each file in test/images directory
test_target = np.genfromtxt('plane_test_target.csv', delimiter=',').astype(int)

# classname (label) for 20 class plane dataset
id_target = np.load('ids_test.npy').item()

accuracy = accuracy_score(test_target, predicted_class_list)
print("Data Test Accuracy = %.3f%%" % (accuracy*100))

f1_macro = f1_score(test_target, predicted_class_list, average='macro')
f1_micro = f1_score(test_target, predicted_class_list, average='micro')
print("F1 Score: Macro = %.3f, Micro = %.3f" % (f1_macro,f1_micro))
# Out:
# Data Test Accuracy = 41.944%
# F1 Score: Macro = 0.408, Micro = 0.419

# %%
# target_names = list(map(str, id_target.values()))
target_names = list(map(str, id_target.keys()))

print(classification_report(test_target, predicted_class_list, target_names=target_names))
# Out:
#                      precision    recall  f1-score   support
#
#                A300       0.11      0.09      0.10        33
#                A310       0.33      0.15      0.21        33
#                A320       0.31      0.48      0.38       134
#                A330       0.25      0.14      0.18        66
#                A340       0.50      0.48      0.49       134
#                A380       0.45      0.39      0.42        33
#              ATR-42       0.35      0.36      0.36        33
#              ATR-72       0.67      0.47      0.55        34
#               An-12       0.58      0.64      0.61        33
#             BAE 146       0.52      0.58      0.55        67
#             BAE-125       0.75      0.55      0.63        33
#     Beechcraft 1900       0.60      0.36      0.45        33
#          Boeing 707       0.19      0.09      0.12        33
#          Boeing 717       0.30      0.18      0.22        34
#          Boeing 727       0.21      0.12      0.15        33
#          Boeing 737       0.32      0.73      0.44       267
#          Boeing 747       0.45      0.43      0.44       133
#          Boeing 757       0.28      0.28      0.28        67
#          Boeing 767       0.26      0.30      0.28       100
#          Boeing 777       0.27      0.36      0.31        67
#               C-130       0.29      0.24      0.26        33
#                C-47       0.20      0.15      0.17        33
#             CRJ-200       0.49      0.62      0.55        34
#             CRJ-700       0.58      0.58      0.58        66
#          Cessna 172       0.42      0.44      0.43        34
#          Cessna 208       0.35      0.24      0.29        33
#     Cessna Citation       0.62      0.46      0.53        67
#      Challenger 600       0.41      0.33      0.37        33
#               DC-10       0.30      0.09      0.14        33
#                DC-3       0.29      0.26      0.28        34
#                DC-6       0.36      0.36      0.36        33
#                DC-8       0.06      0.03      0.04        33
#                DC-9       0.10      0.06      0.07        34
#               DH-82       0.50      0.36      0.42        33
#               DHC-1       0.67      0.48      0.56        33
#               DHC-6       0.63      0.35      0.45        34
#              DR-400       0.65      0.50      0.57        34
#              Dash 8       0.45      0.36      0.40        66
#         Dornier 328       0.49      0.52      0.50        33
#             EMB-120       0.46      0.39      0.43        33
#       Embraer E-Jet       0.50      0.27      0.35       100
#     Embraer ERJ 145       0.47      0.54      0.50        67
#  Embraer Legacy 600       0.45      0.39      0.42        33
# Eurofighter Typhoon       0.59      0.68      0.63        34
#                F-16       0.56      0.73      0.63        33
#               FA-18       0.33      0.39      0.36        33
#         Falcon 2000       0.48      0.68      0.56        34
#          Falcon 900       0.66      0.64      0.65        33
#          Fokker 100       0.40      0.24      0.30        33
#           Fokker 50       0.56      0.41      0.47        34
#           Fokker 70       0.59      0.30      0.40        33
#      Global Express       0.70      0.42      0.53        33
#          Gulfstream       0.65      0.61      0.63        67
#             Hawk T1       0.92      0.67      0.77        33
#               Il-76       0.81      0.50      0.62        34
#            King Air       0.56      0.27      0.37        33
#              L-1011       0.21      0.12      0.15        33
#               MD-11       0.33      0.12      0.18        33
#               MD-80       0.28      0.39      0.32        67
#               MD-90       0.24      0.12      0.16        33
#          Metroliner       0.39      0.26      0.32        34
#               PA-28       0.61      0.61      0.61        33
#               SR-20       0.53      0.59      0.56        34
#           Saab 2000       0.77      0.61      0.68        33
#            Saab 340       0.57      0.24      0.34        33
#            Spitfire       0.55      0.50      0.52        34
#             Tornado       0.58      0.58      0.58        33
#              Tu-134       0.72      0.39      0.51        33
#              Tu-154       0.35      0.38      0.37        34
#              Yak-42       0.62      0.48      0.54        33
#
#         avg / total       0.44      0.42      0.41      3333
